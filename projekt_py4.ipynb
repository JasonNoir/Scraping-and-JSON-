# %%
import tkinter as tk
import tkinter.font as font
import json

# %%
import json




with open ('scores.json') as f:
    jsondata = json.load(f)





for element in jsondata['events']:
    leage =  element['tournament']['name']
    status = element["status"]["description"]
    hometeam = element['homeTeam']['name']
    awayteam = element['awayTeam']['name']
    homescore = element["homeScore"]["current"]
    awayscore = element['awayScore']['current']
    idTeam = element['tournament']["category"]["alpha2"]
    team1 =[element['homeTeam']['name']]
    team =[element['homeTeam']['name']]
    
    print(leage+"\n"+ hometeam+ " vs " + awayteam)
    print(status,"  ",homescore ,"|", awayscore)
    print(team)
    
    
    


root = tk.Tk()

root.geometry("500x500")

root.resizable(False,False)

myFont = font.Font(size=10)
myFont2 = font.Font(size=15)



def Listenauswahl():

    Indices = listbox.curselection()
   
    print(Indices)
 
    print(listbox.get(Indices[0]))
  
    for index in Indices:
      
        print(index)
        print("Du hast ausgewählt:",listbox.get(index))
            


leage1 = jsondata['events'][0]['tournament']['name']
leage2 = jsondata['events'][1]['tournament']['name']
leage3 = jsondata['events'][2]['tournament']['name']
leage4 = jsondata['events'][3]['tournament']['name']
leage5 = jsondata['events'][4]['tournament']['name']

liste = [leage1,leage2,leage3,leage4,leage5]






Varliste = tk.StringVar(value=liste)

listbox = tk.Listbox(root,listvariable=Varliste,height=10,width=80,selectmode="multiple")

listbox.place(x=10,y=20)














root.mainloop()
# Out:
# A-League Men
# Brisbane Roar vs Central Coast Mariners
# 1st half    0 | 0
# ['Brisbane Roar']
# J.League
# Avispa Fukuoka vs FC Tokyo
# 2nd half    3 | 1
# ['Avispa Fukuoka']
# Queensland Premier League 3, South Coast, Women
# Mudgeeraba vs Robina City FC
# 2nd half    0 | 1
# ['Mudgeeraba']
# Vysshaya Liga Reserve
# Dinamo Minsk Reserve vs BATE Borisov Reserve
# 1st half    0 | 0
# ['Dinamo Minsk Reserve']
# 2nd League
# FC Bavarians vs Tuuliin Tom Tulnuud
# 2nd half    3 | 1
# ['FC Bavarians']
